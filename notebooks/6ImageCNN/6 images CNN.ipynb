# %%
# Import some libraries

import torch
import torchvision
from torch import nn
from torch.utils.data import DataLoader
from torchvision import transforms
import torchvision.datasets as datasets

import os
import pickle
import numpy as np

from skimage import io

from matplotlib import pyplot as plt
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['image.interpolation'] = 'nearest'
mpl.rcParams['figure.figsize'] = 15, 25

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
input_dim = (3, 256, 306)

# %%
import ConvAE_AutoConf as ConvAE

feature_maps = 96
depth = 10
pooling_freq = 2 # large number to disable pooling layers
batch_norm_freq = 2
strided_conv_freq = 6
strided_conv_feature_maps = 32
code_size = 8

CONV_ENC_BLOCK = [("conv1", feature_maps), ("relu1", None)]
CONV_ENC_LAYERS = ConvAE.create_network(
    CONV_ENC_BLOCK, depth, 
    pooling_freq=pooling_freq,
    strided_conv_freq=strided_conv_freq, 
    strided_conv_channels=strided_conv_feature_maps,
    batch_norm_freq=batch_norm_freq)

CONV_ENC_NW = CONV_ENC_LAYERS + [("flatten1", None), ("linear1", 1024), ("relu1", None), ("linear1", 256)]
model = ConvAE.ConvAE(input_dim, enc_config=CONV_ENC_NW, store_activations=False)
# print("Encoder Nw Spec:")
# CONV_ENC_NW
print(model)
# Out:
# ConvAE(
#   (encoder): ModuleList(
#     (0): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU()
#     (2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): ReLU()
#     (8): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (9): ReLU()
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (13): ReLU()
#     (14): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (15): ReLU()
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(96, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (18): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (20): ReLU()
#     (21): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (22): ReLU()
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (26): ReLU()
#     (27): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (28): ReLU()
#     (29): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (30): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (31): Reshape()
#     (32): Linear(in_features=1536, out_features=1024, bias=True)
#     (33): ReLU()
#     (34): Linear(in_features=1024, out_features=256, bias=True)
#   )
#   (decoder): ModuleList(
#     (0): Linear(in_features=256, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=1536, bias=True)
#     (3): Reshape()
#     (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (6): ReLU()
#     (7): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (8): ReLU()
#     (9): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (12): ReLU()
#     (13): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (14): ReLU()
#     (15): ConvTranspose2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (16): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ConvTranspose2d(32, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (18): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (19): ReLU()
#     (20): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (21): ReLU()
#     (22): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (23): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (25): ReLU()
#     (26): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (27): ReLU()
#     (28): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (29): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (30): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#     (31): ReLU()
#     (32): ConvTranspose2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (33): ReLU()
#     (34): ConvTranspose2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (tanh): Tanh()
# )

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.size()[0], -1)

class DeFlatten(nn.Module):
    def __init__(self, *args):
        super(DeFlatten, self).__init__()
        self.shape = args

    def forward(self, x):
        return x.view(self.shape)

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.Conv2d(96, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
            nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
            Flatten(),
            nn.Linear(in_features=1536, out_features=1024, bias=True),
            nn.ReLU(),
            nn.Linear(in_features=1024, out_features=256, bias=True),
        )
    def forward(self, x):
        x = self.encoder(x)
        return x
    
model = CNN().to(device)
criterion = nn.MSELoss()

# %%
from torchsummary import summary

summary(model, (input_dim))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 96, 256, 306]           2,592
#               ReLU-2         [-1, 96, 256, 306]               0
#             Conv2d-3         [-1, 96, 256, 306]          82,944
#               ReLU-4         [-1, 96, 256, 306]               0
#          MaxPool2d-5         [-1, 96, 128, 153]               0
#        BatchNorm2d-6         [-1, 96, 128, 153]             192
#             Conv2d-7         [-1, 96, 128, 153]          82,944
#               ReLU-8         [-1, 96, 128, 153]               0
#             Conv2d-9         [-1, 96, 128, 153]          82,944
#              ReLU-10         [-1, 96, 128, 153]               0
#         MaxPool2d-11           [-1, 96, 64, 76]               0
#       BatchNorm2d-12           [-1, 96, 64, 76]             192
#            Conv2d-13           [-1, 96, 64, 76]          82,944
#              ReLU-14           [-1, 96, 64, 76]               0
#            Conv2d-15           [-1, 96, 64, 76]          82,944
#              ReLU-16           [-1, 96, 64, 76]               0
#         MaxPool2d-17           [-1, 96, 32, 38]               0
#            Conv2d-18           [-1, 32, 16, 19]          27,648
#       BatchNorm2d-19           [-1, 32, 16, 19]              64
#            Conv2d-20           [-1, 96, 16, 19]          27,648
#              ReLU-21           [-1, 96, 16, 19]               0
#            Conv2d-22           [-1, 96, 16, 19]          82,944
#              ReLU-23           [-1, 96, 16, 19]               0
#         MaxPool2d-24             [-1, 96, 8, 9]               0
#       BatchNorm2d-25             [-1, 96, 8, 9]             192
#            Conv2d-26             [-1, 96, 8, 9]          82,944
#              ReLU-27             [-1, 96, 8, 9]               0
#            Conv2d-28             [-1, 96, 8, 9]          82,944
#              ReLU-29             [-1, 96, 8, 9]               0
#         MaxPool2d-30             [-1, 96, 4, 4]               0
#       BatchNorm2d-31             [-1, 96, 4, 4]             192
#           Flatten-32                 [-1, 1536]               0
#            Linear-33                 [-1, 1024]       1,573,888
#              ReLU-34                 [-1, 1024]               0
#            Linear-35                  [-1, 256]         262,400
# ================================================================
# Total params: 2,558,560
# Trainable params: 2,558,560
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.90
# Forward/backward pass size (MB): 339.24
# Params size (MB): 9.76
# Estimated Total Size (MB): 349.89
# ----------------------------------------------------------------

# %%
from IPython.display import clear_output

num_epochs = 50
dataset_len = len(train_loader.dataset)
val_dataset_len = len(val_loader.dataset)
validation_losses = []
training_losses = []
for epoch in range(num_epochs):
    torch.cuda.empty_cache()
    total = 0
    for data in train_loader:
        img, expected_output = data
        img = img.to(device)
        # ===================forward=====================
        output = model(img) 
        loss = criterion(output, expected_output)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
                
        clear_output(wait=True)
        total += len(data[0])     
        if len(validation_losses) == 0:
            print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, training loss:{loss.item():.4f}')
        else:
            print(f'epoch [{epoch + 1}/{num_epochs}], data trained:{100 * total / dataset_len :.3f}%, training loss:{loss.item():.4f}, validation loss (prev epoch):{validation_losses[-1]}')
    
    with torch.no_grad():
        total_vloss = 0
        for val_data in val_loader:
            vimg, v_expected_output = val_data
            vimg = vimg.to(device)
            voutput = model(vimg)
            vloss = criterion(voutput, v_expected_output)
            total_vloss += vloss
        validation_losses.append(total_vloss)
        
    with torch.no_grad():
        total_tloss = 0
        for train_data in train_loader:
            timg, t_expected_output = train_data
            timg = timg.to(device)
            toutput = model(timg)
            tloss = criterion(toutput, t_expected_output)
            total_tloss += tloss
        training_losses.append(total_tloss)

    if (epoch + 1) % 10 == 0:
        torch.save(model, 'Models/gpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
        model.to(torch.device('cpu'))
        torch.save(model, 'Models/cpu_model_b64_w2_e'+ str(epoch + 1) +'.pt')
        model.to(device)
